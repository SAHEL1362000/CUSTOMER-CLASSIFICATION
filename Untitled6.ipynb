# %% [markdown]
# <a href="https://colab.research.google.com/github/SAHEL1362000/CUSTOMER-CLASSIFICATION/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
np.random.seed(42)
n_customers = 500
ages = np.random.randint(18, 65, n_customers)
genders = np.random.choice([0,1] , n_customers)
income = np.random.normal(50, 15, n_customers)
purchase_freq = np.random.poisson(3, n_customers)

churn = ((income < 40) | (purchase_freq < 3)).astype(int)


df_customers = pd.DataFrame({
    'Age': ages,
    'Gender': genders,
    'Income': income,
    'Purchase Frequency': purchase_freq,
    'Churn': churn
})

data.to_csv('customers_data.csv', index=False)
print(data.head())
data = pd.DataFrame({
    'Age': ages,
    'Gender': genders,
    'Income': income,
    'Purchase Frequency': purchase_freq,
    'Churn': churn
})
df_customers.to_csv('customer_data.csv', index=False)
print(df_customers.head())
# Out:
#    Age  Gender     Income  Purchase Frequency  Churn
# 0   56       0  39.504117                   1      1
# 1   46       0  53.209699                   4      0
# 2   32       0  48.315079                   2      1
# 3   60       0  46.685456                   2      1
# 4   25       0  59.212501                   3      0
#    Age  Gender     Income  Purchase Frequency  Churn
# 0   56       0  39.504117                   1      1
# 1   46       0  53.209699                   4      0
# 2   32       0  48.315079                   2      1
# 3   60       0  46.685456                   2      1
# 4   25       0  59.212501                   3      0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('customer_data.csv')

# %%
df.head()
# Out:
#    Age  Gender     Income  Purchase Frequency  Churn
# 0   56       0  39.504117                   1      1
# 1   46       0  53.209699                   4      0
# 2   32       0  48.315079                   2      1
# 3   60       0  46.685456                   2      1
# 4   25       0  59.212501                   3      0

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 500 non-null    int64
#  1   Gender              500 non-null    int64
#  2   Income              500 non-null    float64
#  3   Purchase Frequency  500 non-null    int64
#  4   Churn               500 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 19.7 KB
# Age                   0
# Gender                0
# Income                0
# Purchase Frequency    0
# Churn                 0
# dtype: int64

# %%
sns.countplot(x='Churn', data=df)
plt.title("Customer Churn Distribution")
plt.show()

sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84        46
#            1       0.84      0.91      0.88        54
#
#     accuracy                           0.86       100
#    macro avg       0.86      0.86      0.86       100
# weighted avg       0.86      0.86      0.86       100
#
#
# Confusion Matrix:
#  [[37  9]
#  [ 5 49]]

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84        46
#            1       0.84      0.91      0.88        54
#
#     accuracy                           0.86       100
#    macro avg       0.86      0.86      0.86       100
# weighted avg       0.86      0.86      0.86       100
#
#
# Confusion Matrix:
#  [[37  9]
#  [ 5 49]]

# %%
new_customer = pd.DataFrame({
    'Age': [28],
    'Gender': [1],
    'Income': [37],
    'Purchase Frequency': [2]
})

prediction  = model.predict(new_customer)[0]
if prediction == 1:
    print("This customer is likely to churn")
else:
    print("This customer is not likely to churn")
# Out:
# This customer is likely to churn
